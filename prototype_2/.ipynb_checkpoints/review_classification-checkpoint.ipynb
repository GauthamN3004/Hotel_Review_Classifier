# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from nltk.corpus import wordnet
from nltk import sent_tokenize,word_tokenize
import nltk
from textblob import *
from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
import warnings
warnings.filterwarnings('ignore')
import re

# %%
df = pd.read_csv("updated_train.csv")
df.head()
# Out:
#                                               review  pos_neg  review_len
# 0  room kind clean strong smell dog gener averag ...        0         248
# 1  stay crown plaza april april staff friendli at...        0        1077
# 2  book hotel hotwir lowest price could find got ...        0        1327
# 3  stay husband son way alaska crui love hotel gr...        1         502
# 4  room one nice clearli updat recent clean bed c...        1         610

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(min_df=2,max_df = 0.5)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(df["review"],df["pos_neg"],test_size=0.2,random_state = 0)

# %%
xtrain = cv.fit_transform(list(xtrain))

# %%
xtest = cv.transform(list(xtest))

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()

# %%
from sklearn.metrics import plot_confusion_matrix

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer()
tfidf_transformer.fit(xtrain)
tfidf_transformer.transform(xtrain)
tfidf_transformer.transform(xtest)
# Out:
# <6735x12573 sparse matrix of type '<class 'numpy.float64'>'
# 	with 326955 stored elements in Compressed Sparse Row format>

# %%
from sklearn.metrics import jaccard_similarity_score,plot_confusion_matrix
from sklearn.naive_bayes import MultinomialNB

# %%
mnb = MultinomialNB()
mnb.fit(xtrain,ytrain)
ypred = mnb.predict(xtest)
plot_confusion_matrix(mnb, xtest, ytest,
                                 display_labels=['Negetive','Positive'],
                                 cmap=plt.cm.Blues,
                                 normalize=None)
print("Jaccard Similarity Score = ",jaccard_similarity_score(ytest,ypred))
# Out:
# Jaccard Similarity Score =  0.875426874536006

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(xtrain,ytrain)
ypred = xgb.predict(xtest)

# %%
disp = plot_confusion_matrix(xgb, xtest, ytest,
                                 display_labels=['Negetive','Positive'],
                                 cmap=plt.cm.Blues,
                                 normalize=None)
print("Jaccard Similarity Score = ",jaccard_similarity_score(ytest,ypred))
# Out:
# Jaccard Similarity Score =  0.8645879732739421

# %% [markdown]
# TESTING

# %%
contractions = {
"ain't": "am not",
"aren't": "are not",
"can't": "cannot",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'll": "he will",
"he's": "he is",
"how'd": "how did",
"how'll": "how will",
"how's": "how is",
"i'd": "I would",
"i'll": "I will",
"i'm": "I am",
"i've": "I have",
"isn't": "is not",
"it'd": "it would",
"it'll": "it will",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so is",
"that'd": "that would",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you would",
"you'll": "you will",
"you're": "you are",
"you've": "you have"
}

# %%
con_keys = list(contractions.keys())
def handle_contractions(review):
    words = review.lower().split()
    for i in range(len(words)):
        if(words[i] in con_keys):
            words[i] = contractions[words[i]]
    sentence = " ".join(words)
    return sentence

# %%
import pickle
opposites = pickle.load(open("opposites.pkl","rb"))
opposites["great"] = "ok"

# %%
opp_keys = list(opposites.keys())
def handle_negation(review):
    review = review.lower()
    review = handle_contractions(review)
    review = sent_tokenize(review)
    final_sent=""
    for sent in review:
        words = word_tokenize(sent)
        words = [x for x in words if x!='the']
        tags = nltk.pos_tag(words)
        i = 0
        while(i<len(words)):
            if(tags[i][0]=="not"):
                for j in range(i+1,len(tags)):
                    if(j>=len(words)):
                        i+=1
                        break
                    if(tags[j][1]=='JJ'):
                        if((tags[j][0] in opp_keys) and (opposites[tags[j][0]]!=None)):
                            words[j] = opposites[tags[j][0]]
                            print(" ".join(words))
                            try:
                                del(words[i])
                                del(tags[i])
                            except:
                                continue
                            break
                        else:
                            i+=1
                            break
                    else:
                        i+=1
                        continue
            else:
                i=i+1
        final_sent+=" ".join(words)
    return final_sent

# %%
def review_prepare(review):
    ps=PorterStemmer()
    review = handle_negation(review)
    review = re.sub('[^a-z]',' ',review)
    review = word_tokenize(review)
    stop_words = stopwords.words("english")
    stop_words.remove("not")
    stop_words.extend(["food","hotel","room"])
    review = [ps.stem(word) for word in review if word not in stop_words]
    review = ' '.join(review)
    return review

# %%
def predict(review):
    review = review_prepare(review)
    print(review)
    review  = cv.transform([review])
    ypred = mnb.predict(review)
    return ypred[0]

# %%
predict("the food was not that great. but the rooms were spacious. overall it was an average experience")
# Out:
# 0 food
# found not
# 3 that
# 4 great
# dound adjective great
# food was not that ok .
# after delete : food was not ok .
# length =  5 5
# delete words
# 0 but
# 0 overall
# food not ok room spaciou overal averag experi
# 1

# %%
predict("not worth the price")
# Out:
# 0 not
# found not
# 1 worth
# dound adjective worth
# not worthlessness price
# after delete : worthlessness price
# length =  2 2
# delete words
# worthless price
# 0

# %%
rubbish = pickle.load(open("common_nouns.pkl","rb"))
len(rubbish)
# Out:
# 300

# %%
rub = []
for i in rubbish:
    pos = i+" good"
    neg = i+" bad"
    if(predict(pos) == predict(neg)):
        rub.append(i)
# Out:
# 0 hotel
# hotel good
# 0 hotel
# hotel bad
# 0 room
# room good
# 0 room
# room bad
# 0 staff
# staff good
# 0 staff
# staff bad
# 0 location
# locat good
# 0 location
# locat bad
# 0 night
# night good
# 0 night
# night bad
# 0 service
# servic good
# 0 service
# servic bad
# 0 breakfast
# breakfast good
# 0 breakfast
# breakfast bad
# 0 stay
# stay good
# 0 stay
# stay bad
# 0 time
# time good
# 0 time
# time bad
# 0 place
# place good
# 0 place
# place bad
# 0 area
# area good
# 0 area
# area bad
# 0 desk
# desk good
# 0 desk
# desk bad
# 0 bed
# bed good
# 0 bed
# bed bad
# 0 day
# day good
# 0 day
# day bad
# 0 floor
# floor good
# 0 floor
# floor bad
# 0 bathroom
# bathroom good
# 0 bathroom
# bathroom bad
# 0 lobby
# lobbi good
# 0 lobby
# lobbi bad
# 0 price
# price good
# 0 price
# price bad
# 0 front
# front good
# 0 front
# front bad
# 0 view
# view good
# 0 view
# view bad
# 0 restaurant
# restaur good
# 0 restaurant
# restaur bad
# 0 food
# food good
# 0 food
# food bad
# 0 pool
# pool good
# 0 pool
# pool bad
# 0 street
# street good
# 0 street
# street bad
# 0 city
# citi good
# 0 city
# citi bad
# 0 business
# busi good
# 0 business
# busi bad
# 0 bar
# bar good
# 0 bar
# bar bad
# 0 trip
# trip good
# 0 trip
# trip bad
# 0 door
# door good
# 0 door
# door bad
# 0 everything
# everyth good
# 0 everything
# everyth bad
# 0 parking
# park good
# 0 parking
# park bad
# 0 morning
# morn good
# 0 morning
# morn bad
# 0 bit
# bit good
# 0 bit
# bit bad
# 0 way
# way good
# 0 way
# way bad
# 0 coffee
# coffe good
# 0 coffee
# coffe bad
# 0 experience
# experi good
# 0 experience
# experi bad
# 0 car
# car good
# 0 car
# car bad
# 0 distance
# distanc good
# 0 distance
# distanc bad
# 0 walk
# walk good
# 0 walk
# walk bad
# 0 noise
# nois good
# 0 noise
# nois bad
# 0 lot
# lot good
# 0 lot
# lot bad
# 0 water
# water good
# 0 water
# water bad
# 0 weekend
# weekend good
# 0 weekend
# weekend bad
# 0 size
# size good
# 0 size
# size bad
# 0 airport
# airport good
# 0 airport
# airport bad
# 0 rate
# rate good
# 0 rate
# rate bad
# 0 suite
# suit good
# 0 suite
# suit bad
# 0 family
# famili good
# 0 family
# famili bad
# 0 shower
# shower good
# 0 shower
# shower bad
# 0 problem
# problem good
# 0 problem
# problem bad
# 0 thing
# thing good
# 0 thing
# thing bad
# 0 value
# valu good
# 0 value
# valu bad
# 0 i
# good
# 0 i
# bad
# 0 money
# money good
# 0 money
# money bad
# 0 property
# properti good
# 0 property
# properti bad
# 0 internet
# internet good
# 0 internet
# internet bad
# 0 husband
# husband good
# 0 husband
# husband bad
# 0 shopping
# shop good
# 0 shopping
# shop bad
# 0 side
# side good
# 0 side
# side bad
# 0 tv
# tv good
# 0 tv
# tv bad
# 0 access
# access good
# 0 access
# access bad
# 0 nothing
# noth good
# 0 nothing
# noth bad
# 0 block
# block good
# 0 block
# block bad
# 0 center
# center good
# 0 center
# center bad
# 0 building
# build good
# 0 building
# build bad
# 0 reception
# recept good
# 0 reception
# recept bad
# 0 week
# week good
# 0 week
# week bad
# 0 home
# home good
# 0 home
# home bad
# 0 year
# year good
# 0 year
# year bad
# 0 corner
# corner good
# 0 corner
# corner bad
# 0 hour
# hour good
# 0 hour
# hour bad
# 0 check
# check good
# 0 check
# check bad
# 0 concierge
# concierg good
# 0 concierge
# concierg bad
# 0 couple
# coupl good
# 0 couple
# coupl bad
# 0 part
# part good
# 0 part
# part bad
# 0 space
# space good
# 0 space
# space bad
# 0 deal
# deal good
# 0 deal
# deal bad
# 0 town
# town good
# 0 town
# town bad
# 0 minute
# minut good
# 0 minute
# minut bad
# 0 dinner
# dinner good
# 0 dinner
# dinner bad
# 0 elevator
# elev good
# 0 elevator
# elev bad
# 0 evening
# even good
# 0 evening
# even bad
# 0 anything
# anyth good
# 0 anything
# anyth bad
# 0 wife
# wife good
# 0 wife
# wife bad
# 0 quality
# qualiti good
# 0 quality
# qualiti bad
# 0 work
# work good
# 0 work
# work bad
# 0 decor
# decor good
# 0 decor
# decor bad
# 0 choice
# choic good
# 0 choice
# choic bad
# 0 shuttle
# shuttl good
# 0 shuttle
# shuttl bad
# 0 downtown
# downtown good
# 0 downtown
# downtown bad
# 0 something
# someth good
# 0 something
# someth bad
# 0 manager
# manag good
# 0 manager
# manag bad
# 0 visit
# visit good
# 0 visit
# visit bad
# 0 conference
# confer good
# 0 conference
# confer bad
# 0 subway
# subway good
# 0 subway
# subway bad
# 0 air
# air good
# 0 air
# air bad
# 0 anyone
# anyon good
# 0 anyone
# anyon bad
# 0 valet
# valet good
# 0 valet
# valet bad
# 0 station
# station good
# 0 station
# station bad
# 0 plenty
# plenti good
# 0 plenty
# plenti bad
# 0 person
# person good
# 0 person
# person bad
# 0 kind
# kind good
# 0 kind
# kind bad
# 0 star
# star good
# 0 star
# star bad
# 0 window
# window good
# 0 window
# window bad
# 0 wine
# wine good
# 0 wine
# wine bad
# 0 end
# end good
# 0 end
# end bad
# 0 customer
# custom good
# 0 customer
# custom bad
# 0 buffet
# buffet good
# 0 buffet
# buffet bad
# 0 line
# line good
# 0 line
# line bad
# 0 fridge
# fridg good
# 0 fridge
# fridg bad
# 0 bedroom
# bedroom good
# 0 bedroom
# bedroom bad
# 0 tub
# tub good
# 0 tub
# tub bad
# 0 phone
# phone good
# 0 phone
# phone bad
# 0 reservation
# reserv good
# 0 reservation
# reserv bad
# 0 book
# book good
# 0 book
# book bad
# 0 location
# locat good
# 0 location
# locat bad
# 0 lounge
# loung good
# 0 lounge
# loung bad
# 0 flight
# flight good
# 0 flight
# flight bad
# 0 king
# king good
# 0 king
# king bad
# 0 everyone
# everyon good
# 0 everyone
# everyon bad
# 0 issue
# issu good
# 0 issue
# issu bad
# 0 park
# park good
# 0 park
# park bad
# 0 one
# one good
# 0 one
# one bad
# 0 charge
# charg good
# 0 charge
# charg bad
# 0 bus
# bu good
# 0 bus
# bu bad
# 0 bath
# bath good
# 0 bath
# bath bad
# 0 fact
# fact good
# 0 fact
# fact bad
# 0 someone
# someon good
# 0 someone
# someon bad
# 0 luggage
# luggag good
# 0 luggage
# luggag bad
# 0 complaint
# complaint good
# 0 complaint
# complaint bad
# 0 arrival
# arriv good
# 0 arrival
# arriv bad
# 0 level
# level good
# 0 level
# level bad
# 0 neighborhood
# neighborhood good
# 0 neighborhood
# neighborhood bad
# 0 carpet
# carpet good
# 0 carpet
# carpet bad
# 0 middle
# middl good
# 0 middle
# middl bad
# 0 cab
# cab good
# 0 cab
# cab bad
# 0 card
# card good
# 0 card
# card bad
# 0 gym
# gym good
# 0 gym
# gym bad
# 0 kitchen
# kitchen good
# 0 kitchen
# kitchen bad
# 0 daughter
# daughter good
# 0 daughter
# daughter bad
# 0 road
# road good
# 0 road
# road bad
# 0 convention
# convent good
# 0 convention
# convent bad
# 0 tv
# tv good
# 0 tv
# tv bad
# 0 wall
# wall good
# 0 wall
# wall bad
# 0 site
# site good
# 0 site
# site bad
# 0 cost
# cost good
# 0 cost
# cost bad
# 0 need
# need good
# 0 need
# need bad
# 0 number
# number good
# 0 number
# number bad
# 0 member
# member good
# 0 member
# member bad
# 0 guest
# guest good
# 0 guest
# guest bad
# 0 order
# order good
# 0 order
# order bad
# 0 name
# name good
# 0 name
# name bad
# 0 furniture
# furnitur good
# 0 furniture
# furnitur bad
# 0 fun
# fun good
# 0 fun
# fun bad
# 0 job
# job good
# 0 job
# job bad
# 0 taxi
# taxi good
# 0 taxi
# taxi bad
# 0 wifi
# wifi good
# 0 wifi
# wifi bad
# 0 toilet
# toilet good
# 0 toilet
# toilet bad
# 0 fruit
# fruit good
# 0 fruit
# fruit bad
# 0 cable
# cabl good
# 0 cable
# cabl bad
# 0 touch
# touch good
# 0 touch
# touch bad
# 0 sleep
# sleep good
# 0 sleep
# sleep bad
# 0 convenient
# conveni good
# 0 convenient
# conveni bad
# 0 garage
# garag good
# 0 garage
# garag bad
# 0 smell
# smell good
# 0 smell
# smell bad
# 0 care
# care good
# 0 care
# care bad
# 0 vacation
# vacat good
# 0 vacation
# vacat bad
# 0 style
# style good
# 0 style
# style bad
# 0 course
# cours good
# 0 course
# cours bad
# 0 traffic
# traffic good
# 0 traffic
# traffic bad
# 0 right
# right good
# 0 right
# right bad
# 0 train
# train good
# 0 train
# train bad
# 0 heart
# heart good
# 0 heart
# heart bad
# 0 check-in
# check good
# 0 check-in
# check bad
# 0 motel
# motel good
# 0 motel
# motel bad
# 0 th
# th good
# 0 th
# th bad
# 0 friend
# friend good
# 0 friend
# friend bad
# 0 group
# group good
# 0 group
# group bad
# 0 feel
# feel good
# 0 feel
# feel bad
# 0 review
# review good
# 0 review
# review bad
# 0 pm
# pm good
# 0 pm
# pm bad
# 0 etc
# etc good
# 0 etc
# etc bad
# 0 clean
# clean good
# 0 clean
# clean bad
# 0 fitness
# fit good
# 0 fitness
# fit bad
# 0 microwave
# microwav good
# 0 microwave
# microwav bad
# 0 stop
# stop good
# 0 stop
# stop bad
# 0 district
# district good
# 0 district
# district bad
# 0 point
# point good
# 0 point
# point bad
# 0 sink
# sink good
# 0 sink
# sink bad
# 0 club
# club good
# 0 club
# club bad
# 0 party
# parti good
# 0 party
# parti bad
# 0 everything
# everyth good
# 0 everything
# everyth bad
# 0 son
# son good
# 0 son
# son bad
# 0 meeting
# meet good
# 0 meeting
# meet bad
# 0 management
# manag good
# 0 management
# manag bad
# 0 hotel
# hotel good
# 0 hotel
# hotel bad
# 0 clerk
# clerk good
# 0 clerk
# clerk bad
# 0 world
# world good
# 0 world
# world bad
# 0 call
# call good
# 0 call
# call bad
# 0 reason
# reason good
# 0 reason
# reason bad
# 0 entrance
# entranc good
# 0 entrance
# entranc bad
# 0 travel
# travel good
# 0 travel
# travel bad
# 0 tea
# tea good
# 0 tea
# tea bad
# 0 budget
# budget good
# 0 budget
# budget bad
# 0 selection
# select good
# 0 selection
# select bad
# 0 construction
# construct good
# 0 construction
# construct bad
# 0 website
# websit good
# 0 website
# websit bad
# 0 ride
# ride good
# 0 ride
# ride bad
# 0 river
# river good
# 0 river
# river bad
# 0 system
# system good
# 0 system
# system bad
# 0 spot
# spot good
# 0 spot
# spot bad
# 0 rest
# rest good
# 0 rest
# rest bad
# 0 balcony
# balconi good
# 0 balcony
# balconi bad
# 0 wedding
# wed good
# 0 wedding
# wed bad
# 0 upgrade
# upgrad good
# 0 upgrade
# upgrad bad
# 0 credit
# credit good
# 0 credit
# credit bad
# 0 maker
# maker good
# 0 maker
# maker bad
# 0 top
# top good
# 0 top
# top bad
# 0 luxury
# luxuri good
# 0 luxury
# luxuri bad
# 0 ice
# ice good
# 0 ice
# ice bad
# 0 closet
# closet good
# 0 closet
# closet bad
# 0 afternoon
# afternoon good
# 0 afternoon
# afternoon bad
# 0 comfy
# comfi good
# 0 comfy
# comfi bad
# 0 menu
# menu good
# 0 menu
# menu bad
# 0 machine
# machin good
# 0 machine
# machin bad
# 0 transportation
# transport good
# 0 transportation
# transport bad
# 0 chain
# chain good
# 0 chain
# chain bad
# 0 table
# tabl good
# 0 table
# tabl bad
# 0 surprise
# surpris good
# 0 surprise
# surpris bad
# 0 facility
# facil good
# 0 facility
# facil bad
# 0 fee
# fee good
# 0 fee
# fee bad
# 0 security
# secur good
# 0 security
# secur bad
# 0 drink
# drink good
# 0 drink
# drink bad
# 0 option
# option good
# 0 option
# option bad
# 0 tourist
# tourist good
# 0 tourist
# tourist bad
# 0 mall
# mall good
# 0 mall
# mall bad
# 0 moment
# moment good
# 0 moment
# moment bad
# 0 class
# class good
# 0 class
# class bad
# 0 spa
# spa good
# 0 spa
# spa bad
# 0 bill
# bill good
# 0 bill
# bill bad
# 0 glass
# glass good
# 0 glass
# glass bad
# 0 meal
# meal good
# 0 meal
# meal bad
# 0 birthday
# birthday good
# 0 birthday
# birthday bad
# 0 dining
# dine good
# 0 dining
# dine bad
# 0 help
# help good
# 0 help
# help bad
# 0 use
# use good
# 0 use
# use bad
# 0 light
# light good
# 0 light
# light bad
# 0 hair
# hair good
# 0 hair
# hair bad
# 0 resort
# resort good
# 0 resort
# resort bad
# 0 man
# man good
# 0 man
# man bad
# 0 refrigerator
# refriger good
# 0 refrigerator
# refriger bad
# 0 game
# game good
# 0 game
# game bad
# 0 music
# music good
# 0 music
# music bad
# 0 hallway
# hallway good
# 0 hallway
# hallway bad
# 0 renovation
# renov good
# 0 renovation
# renov bad
# 0 house
# hous good
# 0 house
# hous bad
# 0 living
# live good
# 0 living
# live bad
# 0 tour
# tour good
# 0 tour
# tour bad
# 0 standard
# standard good
# 0 standard
# standard bad
# 0 request
# request good
# 0 request
# request bad
# 0 bottle
# bottl good
# 0 bottle
# bottl bad
# 0 type
# type good
# 0 type
# type bad
# 0 drive
# drive good
# 0 drive
# drive bad
# 0 paper
# paper good
# 0 paper
# paper bad
# 0 event
# event good
# 0 event
# event bad
# 0 store
# store good
# 0 store
# store bad
# 0 pleasure
# pleasur good
# 0 pleasure
# pleasur bad
# 0 sofa
# sofa good
# 0 sofa
# sofa bad
# 0 computer
# comput good
# 0 computer
# comput bad
# 0 everyone
# everyon good
# 0 everyone
# everyon bad
# 0 holiday
# holiday good
# 0 holiday
# holiday bad
# 0 chair
# chair good
# 0 chair
# chair bad
# 0 shop
# shop good
# 0 shop
# shop bad
# 0 lunch
# lunch good
# 0 lunch
# lunch bad
# 0 fan
# fan good
# 0 fan
# fan bad
# 0 brand
# brand good
# 0 brand
# brand bad
# 0 office
# offic good
# 0 office
# offic bad
# 0 lady
# ladi good
# 0 lady
# ladi bad
# 0 bonus
# bonu good
# 0 bonus
# bonu bad
# 0 min
# min good
# 0 min
# min bad
# 0 guy
# guy good
# 0 guy
# guy bad
# 0 ..
# good
# 0 ..
# bad
# 0 centre
# centr good
# 0 centre
# centr bad
# 0 downside
# downsid good
# 0 downside
# downsid bad
# 0 pressure
# pressur good
# 0 pressure
# pressur bad
# 0 ....
# good
# 0 ....
# bad
# 0 housekeeping
# housekeep good
# 0 housekeeping
# housekeep bad
# 0 attention
# attent good
# 0 attention
# attent bad
# 0 screen
# screen good
# 0 screen
# screen bad
# 0 comfort
# comfort good
# 0 comfort
# comfort bad
# 0 square
# squar good
# 0 square
# squar bad
# 0 key
# key good
# 0 key
# key bad
# 0 juice
# juic good
# 0 juice
# juic bad
# 0 variety
# varieti good
# 0 variety
# varieti bad
# 0 case
# case good
# 0 case
# case bad
# 0 look
# look good
# 0 look
# look bad
# 0 beach
# beach good
# 0 beach
# beach bad
# 0 atmosphere
# atmospher good
# 0 atmosphere
# atmospher bad
# 0 unit
# unit good
# 0 unit
# unit bad
# 0 hall
# hall good
# 0 hall
# hall bad

# %%
pickle.dump(cv,open("count_vectorizer.sav","wb"))
pickle.dump(mnb,open("classifier.sav","wb"))

# %%
pickle.dump(contractions,open("contractions.pkl","wb"))
